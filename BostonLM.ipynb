# %% [markdown]
# # <font color="red">Boston Housing Prediction</font>

# %% [markdown]
# ## Import the Library

# %%
import pandas as pd

# %% [markdown]
# ## Import the Datasets

# %%
# Load the dataset
boston = pd.read_csv('Datasets/BostonHousingData.csv')
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ## Datasets Description

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Data Visualization

# %%
boston.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
boston[boston.isnull().any(axis=1)] # at least one column has null values
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 4     0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# 6     0.08829  12.5   7.87   NaN  0.524  6.012  66.6  5.5605    5  311
# 9     0.17004  12.5   7.87   NaN  0.524  6.004  85.9  6.5921    5  311
# 14    0.63796   0.0   8.14   NaN  0.538  6.096  84.5  4.4619    4  307
# 35    0.06417   0.0   5.96   0.0  0.499  5.933  68.2  3.3603    5  279
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 473   4.64689   0.0  18.10   0.0  0.614  6.980  67.6  2.5329   24  666
# 479  14.33370   0.0  18.10   NaN  0.614  6.229  88.0  1.9512   24  666
# 482   5.73116   0.0  18.10   NaN  0.532  7.061  77.0  3.4106   24  666
# 501   0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 505   0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 4       18.7  396.90    NaN  36.2
# 6       15.2  395.60  12.43  22.9
# ...

# %%
boston[boston.isnull().sum(axis=1) > 1] # at least two columns have null values
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE      DIS  RAD  TAX  \
# 133   0.32982   NaN    NaN   0.0  0.624  5.822  95.4   2.4699    4  437
# 173   0.09178   0.0    NaN   0.0  0.510  6.416   NaN   2.6463    5  296
# 245   0.19133  22.0    NaN   NaN  0.431  5.605  70.2   7.9549    7  330
# 350   0.06211   NaN   1.25   0.0  0.429  6.490  44.4   8.7921    1  335
# 355   0.10659   NaN   1.91   0.0  0.413  5.936   NaN  10.5857    4  334
# 376  15.28800   0.0  18.10   NaN  0.671  6.649  93.3   1.3449   24  666
# 458   7.75223   NaN    NaN   0.0  0.713  6.301  83.7   2.7831   24  666
# 465       NaN   0.0  18.10   NaN  0.655  5.759  48.2   3.0665   24  666
#
#      PTRATIO       B  LSTAT  MEDV
# 133     21.2  388.69  15.03  18.4
# 173     16.6  395.50   9.04  23.6
# 245     19.1  389.13  18.46  18.5
# 350     19.7  396.90    NaN  22.9
# 355     22.0  376.04   5.57  20.6
# 376     20.2  363.02    NaN  13.9
# 458     20.2  272.21  16.23  14.9
# 465     20.2  334.40  14.13  19.9

# %%
boston[boston.isnull().sum(axis=1) > 2] # at least three columns have null values
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []

# %% [markdown]
# Not available, that means maximum null is 2
